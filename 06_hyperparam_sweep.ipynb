# %%
# Data manipulation
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio

# Machine learning
import lightgbm as lgb

# Optimization
import optuna
import optuna.visualization as vis

# System utilities
import os
from PIL import Image
import joblib

from pygam import LinearGAM
from sklearn.metrics import r2_score

# %%
#lidar-based target data
lidar_path = 'data/raster/lidar_products/2019_lidar_cover.tif'

#rap data (predictor)
rap_path = 'data/raster/rap/woody_cover_2019.tif'

#static terrain predictors
dem_path = 'data/raster/ned/ned.tif'
slope_path = 'data/raster/terrain/slope.tif'
hli_path = 'data/raster/terrain/hli.tif'
twi_path = 'data/raster/terrain/twi.tif'
covertype_path = 'data/raster/terrain/covertype.tif'
#train sample locations
train_points_path = 'data/vector/train_points_with_folds.geojson'

gpd_train_points = gpd.read_file(train_points_path)

# Read raster data for all points first
with rasterio.open(lidar_path) as src:
    lidar = [x[0] for x in src.sample([(p.x, p.y) for p in gpd_train_points.geometry])]

with rasterio.open(rap_path) as src:
    rap = [x[0] for x in src.sample([(p.x, p.y) for p in gpd_train_points.geometry])]

with rasterio.open(dem_path) as src:
    dem = [x[0] for x in src.sample([(p.x, p.y) for p in gpd_train_points.geometry])]

with rasterio.open(slope_path) as src:
    slope = [x[0] for x in src.sample([(p.x, p.y) for p in gpd_train_points.geometry])]

with rasterio.open(hli_path) as src:
    hli = [x[0] for x in src.sample([(p.x, p.y) for p in gpd_train_points.geometry])]

with rasterio.open(twi_path) as src:
    twi = [x[0] for x in src.sample([(p.x, p.y) for p in gpd_train_points.geometry])]

Y = np.array(lidar)

# Create feature dataframe for all points, including tpi values for each ngb_val
X = pd.DataFrame({
    'rap': rap,
    'dem': dem, 
    'slope': slope,
    'hli': hli,
    'twi': twi
})

# Pre-allocate arrays for tpi and weights
tpi_values = {}

ngb_vals = [30, 60, 120, 240, 480, 960, 1920]

# Iterate over possible parameter values and read corresponding rasters into X
for ngb_val in ngb_vals:
    tpi_path = f'data/raster/terrain/tpi_{ngb_val}.tif'
    with rasterio.open(tpi_path) as src:
        tpi_values[ngb_val] = [x[0] for x in src.sample([(p.x, p.y) for p in gpd_train_points.geometry])]

# %%
def normalized_gini(y_pred, y_true):
    """
    Computes the normalized Gini coefficient.
    
    Parameters:
    -----------
    y_pred : array-like
        The predicted values (e.g., model predictions).
    y_true : array-like
        The true target values.
    
    Returns:
    --------
    float
        The normalized Gini coefficient.
    """
    def sum_gini(a_pred, a_true):
        # Sort true values by descending predicted values
        order = np.argsort(-a_pred)
        a_true_sorted = a_true[order]
        
        # Construct the random cumulative array
        n = len(a_pred)
        random_cum = np.arange(1, n+1) / n
        
        # Calculate the Lorentz curve (cumulative) for the sorted true values
        lorentz = np.cumsum(a_true_sorted) / np.sum(a_true_sorted)
        
        # Gini is the area between the Lorentz curve and the uniform distribution
        return np.sum(lorentz - random_cum)
    
    return sum_gini(np.array(y_pred).astype(int), np.array(y_true).astype(int)) / sum_gini(np.array(y_true).astype(int), np.array(y_true).astype(int))

#def objective(trial):
def objective(trial, X, tpi_values, Y, gpd_train_points):
    params = {
        'objective': 'tweedie',
        'metric': None,
        'random_state': 42,
        'n_jobs': 1,
        'verbosity': -1,
        'n_estimators': trial.suggest_int('n_estimators', 250, 3000),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'max_depth': trial.suggest_int('max_depth', 10, 50),
        'subsample_freq': trial.suggest_int('subsample_freq', 0, 30),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'tweedie_variance_power': trial.suggest_float('tweedie_variance_power', 1.1, 1.95),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 10, 1000),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 50),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-2, 1e1, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-4, 1e1, log=True),
        'min_split_gain': trial.suggest_float('min_split_gain', 1e-8, 1e-6, log=True),
        'min_child_weight': trial.suggest_float('min_child_weight', 1e-5, 1e1, log=True),
        'tpi_ngb': trial.suggest_categorical('tpi_ngb', ngb_vals),
        'n_splines': trial.suggest_int('n_splines', 10, 30),
    }
    
    def process_fold(fold_idx, params, X, tpi_values, Y, gpd_train_points):
        train_mask = (gpd_train_points['fold'] != fold_idx)
        test_mask = (gpd_train_points['fold'] == fold_idx)

        # Add tpi to the feature dataframe
        X_fold = X.copy()
        X_fold['tpi'] = tpi_values[params['tpi_ngb']]

        X_train = X_fold[train_mask]
        X_test = X_fold[test_mask]
        y_train = np.array(Y)[train_mask]
        y_test = np.array(Y)[test_mask]

        # Create the LightGBM model
        lgb_model = lgb.LGBMRegressor(**params)

        # Fit the LightGBM model
        lgb_model.fit(X_train, y_train)

        # 1. Predict with LightGBM on train and test sets
        lgb_train_preds = lgb_model.predict(X_train)
        lgb_test_preds = lgb_model.predict(X_test)

        # 2. Stack a GAM
        gam = LinearGAM(n_splines=params['n_splines'])
        gam.fit(lgb_train_preds.reshape(-1, 1), y_train)

        # 4. Predict with the GAM model
        final_preds = gam.predict(lgb_test_preds.reshape(-1, 1))
        final_preds = np.clip(final_preds, 0, 100)

        # 5. Evaluate the stacked model
        giniscore = normalized_gini(final_preds, y_test)
        r2score = r2_score(y_test, final_preds)

        return np.mean([giniscore, r2score])

    num_folds = 5

    scores = joblib.Parallel(n_jobs=num_folds)(
        joblib.delayed(process_fold)(fold_idx, params, X, tpi_values, Y, gpd_train_points)
        for fold_idx in range(num_folds)
    )
    final_score = np.mean(scores)
    if final_score > 0 and final_score < 1:
        return final_score
    else:
        return 0

# %%
results_dir = f'results/optimization'
os.makedirs(results_dir, exist_ok=True)

# Define the save_study_callback function
def save_study_callback(study, trial):
    joblib.dump(study, os.path.join(results_dir, "study.pkl"))

    values = [t.value for t in study.trials]
    #min_value = np.median(values) * 0.8
    #max_value = np.max(values) + 0.01

    fig_history = vis.plot_optimization_history(study)
    #fig_history.update_yaxes(range=[min_value, max_value])  # Set y-axis range
    fig_history.write_image(os.path.join(results_dir, "optimization_history.png"))

    fig_slice = vis.plot_slice(study)
    #fig_slice.update_yaxes(range=[min_value, max_value])  # Set y-axis range
    fig_slice.write_image(os.path.join(results_dir, "slice_plot.png"))

trial_count = 150

study = optuna.create_study(direction='maximize')
study.optimize(lambda trial: objective(trial, X, tpi_values, Y, gpd_train_points),
                n_trials=trial_count, callbacks=[save_study_callback])

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2025-01-15 22:38:56,427] A new study created in memory with name: no-name-9fa5f8f3-4e15-4337-ad8a-77253b693d1d
# [I 2025-01-15 22:39:16,555] Trial 0 finished with value: 0.6888555177468159 and parameters: {'n_estimators': 1377, 'subsample': 0.7046372292735499, 'max_depth': 15, 'subsample_freq': 1, 'colsample_bytree': 0.5016902247730652, 'tweedie_variance_power': 1.5177153882044048, 'learning_rate': 0.0006077494557096616, 'num_leaves': 444, 'min_child_samples': 24, 'reg_alpha': 0.07567437756066178, 'reg_lambda': 1.2829226813567438, 'min_split_gain': 7.32502894801912e-08, 'min_child_weight': 0.0001253704323556288, 'tpi_ngb': 240, 'n_splines': 23}. Best is trial 0 with value: 0.6888555177468159.
# [I 2025-01-15 22:39:42,381] Trial 1 finished with value: 0.6643747303214316 and parameters: {'n_estimators': 2584, 'subsample': 0.7027785321588713, 'max_depth': 10, 'subsample_freq': 9, 'colsample_bytree': 0.9847527416402613, 'tweedie_variance_power': 1.7975342707985185, 'learning_rate': 0.01802371206157163, 'num_leaves': 177, 'min_child_samples': 44, 'reg_alpha': 1.0279102281177597, 'reg_lambda': 1.4728189729636885, 'min_split_gain': 1.1838767399220166e-07, 'min_child_weight': 2.7621201160492403, 'tpi_ngb': 120, 'n_splines': 10}. Best is trial 0 with value: 0.6888555177468159.
# [I 2025-01-15 22:39:49,734] Trial 2 finished with value: 0.6109024845822978 and parameters: {'n_estimators': 762, 'subsample': 0.5190043615462238, 'max_depth': 47, 'subsample_freq': 20, 'colsample_bytree': 0.9536684814427436, 'tweedie_variance_power': 1.7957377421847889, 'learning_rate': 0.058290719270199194, 'num_leaves': 187, 'min_child_samples': 39, 'reg_alpha': 4.375747538080965, 'reg_lambda': 0.7457505624902474, 'min_split_gain': 9.716089351831021e-08, 'min_child_weight': 0.045754063064630424, 'tpi_ngb': 1920, 'n_splines': 11}. Best is trial 0 with value: 0.6888555177468159.
# [I 2025-01-15 22:40:35,730] Trial 3 finished with value: 0.7119866595814001 and parameters: {'n_estimators': 1854, 'subsample': 0.7770238414350956, 'max_depth': 38, 'subsample_freq': 23, 'colsample_bytree': 0.8565181971928888, 'tweedie_variance_power': 1.628622808845596, 'learning_rate': 0.00033814531287871153, 'num_leaves': 791, 'min_child_samples': 3, 'reg_alpha': 3.086438394898221, 'reg_lambda': 0.05766760617463544, 'min_split_gain': 8.474016627657169e-08, 'min_child_weight': 9.843957543157924e-05, 'tpi_ngb': 480, 'n_splines': 21}. Best is trial 3 with value: 0.7119866595814001.
# [I 2025-01-15 22:40:54,127] Trial 4 finished with value: 0.7159586788207477 and parameters: {'n_estimators': 1133, 'subsample': 0.9691658390205193, 'max_depth': 44, 'subsample_freq': 10, 'colsample_bytree': 0.5900205606481219, 'tweedie_variance_power': 1.6793189955135623, 'learning_rate': 0.0008880505213591444, 'num_leaves': 797, 'min_child_samples': 45, 'reg_alpha': 0.01466911423479618, 'reg_lambda': 0.0004508578399281286, 'min_split_gain': 6.151573652268032e-07, 'min_child_weight': 0.00011298031309328313, 'tpi_ngb': 120, 'n_splines': 10}. Best is trial 4 with value: 0.7159586788207477.
# [I 2025-01-15 22:41:12,246] Trial 5 finished with value: 0.7198340510032851 and parameters: {'n_estimators': 1151, 'subsample': 0.5338913363506641, 'max_depth': 22, 'subsample_freq': 28, 'colsample_bytree': 0.8672035411147969, 'tweedie_variance_power': 1.4985134797609125, 'learning_rate': 0.00039820131242010144, 'num_leaves': 463, 'min_child_samples': 14, 'reg_alpha': 0.296641943334648, 'reg_lambda': 0.8094866656831291, 'min_split_gain': 2.4190568181929964e-07, 'min_child_weight': 0.05307481974459035, 'tpi_ngb': 30, 'n_splines': 17}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:41:30,240] Trial 6 finished with value: 0.683499669263635 and parameters: {'n_estimators': 1739, 'subsample': 0.9036277992076382, 'max_depth': 10, 'subsample_freq': 14, 'colsample_bytree': 0.5709549656158199, 'tweedie_variance_power': 1.6771059510794168, 'learning_rate': 0.0005998384044359051, 'num_leaves': 270, 'min_child_samples': 44, 'reg_alpha': 0.016100531175729862, 'reg_lambda': 0.32990051069830784, 'min_split_gain': 2.1952374028899504e-08, 'min_child_weight': 6.733618536786641e-05, 'tpi_ngb': 30, 'n_splines': 18}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:42:18,291] Trial 7 finished with value: 0.6747851627519517 and parameters: {'n_estimators': 2511, 'subsample': 0.7622304114774978, 'max_depth': 30, 'subsample_freq': 14, 'colsample_bytree': 0.5831315108630359, 'tweedie_variance_power': 1.3555151487399566, 'learning_rate': 0.00736613987139315, 'num_leaves': 390, 'min_child_samples': 33, 'reg_alpha': 4.0256831099343975, 'reg_lambda': 0.0006508353352101473, 'min_split_gain': 2.436375040068388e-08, 'min_child_weight': 0.46126013619115586, 'tpi_ngb': 1920, 'n_splines': 14}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:42:43,544] Trial 8 finished with value: 0.6654021537886123 and parameters: {'n_estimators': 1436, 'subsample': 0.6480581354275103, 'max_depth': 18, 'subsample_freq': 21, 'colsample_bytree': 0.8243787666576885, 'tweedie_variance_power': 1.1504256178187109, 'learning_rate': 0.05625116342802672, 'num_leaves': 953, 'min_child_samples': 19, 'reg_alpha': 7.847609826505905, 'reg_lambda': 0.0036204585571991826, 'min_split_gain': 1.2451056500542829e-08, 'min_child_weight': 1.1645550961058189e-05, 'tpi_ngb': 1920, 'n_splines': 14}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:43:09,570] Trial 9 finished with value: 0.6704832655997593 and parameters: {'n_estimators': 1989, 'subsample': 0.5325566044251677, 'max_depth': 36, 'subsample_freq': 0, 'colsample_bytree': 0.5547904976401584, 'tweedie_variance_power': 1.8261928373546954, 'learning_rate': 0.009274204612347726, 'num_leaves': 179, 'min_child_samples': 46, 'reg_alpha': 0.05459667055656635, 'reg_lambda': 0.0063189722764791095, 'min_split_gain': 2.7368627558182316e-08, 'min_child_weight': 0.10565470492903557, 'tpi_ngb': 1920, 'n_splines': 10}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:43:13,524] Trial 10 finished with value: 0.7017143540515343 and parameters: {'n_estimators': 313, 'subsample': 0.5992898385073919, 'max_depth': 25, 'subsample_freq': 30, 'colsample_bytree': 0.7359399720477929, 'tweedie_variance_power': 1.393862041801301, 'learning_rate': 0.0001019011622280187, 'num_leaves': 565, 'min_child_samples': 10, 'reg_alpha': 0.4069899011608925, 'reg_lambda': 8.957106669629658, 'min_split_gain': 6.517357003219252e-07, 'min_child_weight': 0.004665260278833081, 'tpi_ngb': 30, 'n_splines': 27}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:43:34,240] Trial 11 finished with value: 0.7141756122903855 and parameters: {'n_estimators': 914, 'subsample': 0.9673382314412191, 'max_depth': 50, 'subsample_freq': 7, 'colsample_bytree': 0.7010158191383982, 'tweedie_variance_power': 1.510935021573533, 'learning_rate': 0.0018965659164489805, 'num_leaves': 638, 'min_child_samples': 16, 'reg_alpha': 0.011531068520773912, 'reg_lambda': 0.000112198322210533, 'min_split_gain': 7.751743028469909e-07, 'min_child_weight': 0.0012613008311209528, 'tpi_ngb': 60, 'n_splines': 17}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:43:49,812] Trial 12 finished with value: 0.6986486277645064 and parameters: {'n_estimators': 892, 'subsample': 0.837612743475858, 'max_depth': 24, 'subsample_freq': 30, 'colsample_bytree': 0.6663891879999275, 'tweedie_variance_power': 1.9260157706223744, 'learning_rate': 0.00236336696388448, 'num_leaves': 747, 'min_child_samples': 32, 'reg_alpha': 0.10788119790050549, 'reg_lambda': 0.1516716217278905, 'min_split_gain': 3.2352728367479364e-07, 'min_child_weight': 0.0019559022245960187, 'tpi_ngb': 960, 'n_splines': 30}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:43:53,384] Trial 13 finished with value: 0.700308628203261 and parameters: {'n_estimators': 1142, 'subsample': 0.9813608831883713, 'max_depth': 41, 'subsample_freq': 9, 'colsample_bytree': 0.8550692686368588, 'tweedie_variance_power': 1.2862734432466612, 'learning_rate': 0.00016175716996506633, 'num_leaves': 13, 'min_child_samples': 10, 'reg_alpha': 0.2735147228612796, 'reg_lambda': 0.020038674951147972, 'min_split_gain': 2.9625722365967844e-07, 'min_child_weight': 0.029413366271377597, 'tpi_ngb': 120, 'n_splines': 14}. Best is trial 5 with value: 0.7198340510032851.
# [I 2025-01-15 22:43:59,882] Trial 14 finished with value: 0.7237039100743324 and parameters: {'n_estimators': 432, 'subsample': 0.8594902515915357, 'max_depth': 31, 'subsample_freq': 24, 'colsample_bytree': 0.7985400902944768, 'tweedie_variance_power': 1.6156830436522132, 'learning_rate': 0.0011114432348858152, 'num_leaves': 857, 'min_child_samples': 30, 'reg_alpha': 0.024217478686726898, 'reg_lambda': 0.00018513200568536677, 'min_split_gain': 3.0078818631280717e-07, 'min_child_weight': 6.742536267110442, 'tpi_ngb': 120, 'n_splines': 23}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:44:03,706] Trial 15 finished with value: 0.7153185577873475 and parameters: {'n_estimators': 328, 'subsample': 0.8613412404443248, 'max_depth': 30, 'subsample_freq': 24, 'colsample_bytree': 0.8007616096748095, 'tweedie_variance_power': 1.571235876644936, 'learning_rate': 0.001356142734694886, 'num_leaves': 920, 'min_child_samples': 29, 'reg_alpha': 0.034357214983613556, 'reg_lambda': 9.920779883572598, 'min_split_gain': 2.3354864763336636e-07, 'min_child_weight': 4.374459257746793, 'tpi_ngb': 30, 'n_splines': 24}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:44:10,895] Trial 16 finished with value: 0.7164726111883872 and parameters: {'n_estimators': 627, 'subsample': 0.5985027648496121, 'max_depth': 22, 'subsample_freq': 26, 'colsample_bytree': 0.9249931865086959, 'tweedie_variance_power': 1.4220996628140292, 'learning_rate': 0.00026479636168442154, 'num_leaves': 618, 'min_child_samples': 23, 'reg_alpha': 0.3413987409446367, 'reg_lambda': 0.0028623983921908748, 'min_split_gain': 1.4433606671536475e-07, 'min_child_weight': 0.540376156033038, 'tpi_ngb': 480, 'n_splines': 20}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:44:20,268] Trial 17 finished with value: 0.7133452581079158 and parameters: {'n_estimators': 578, 'subsample': 0.8133151980641165, 'max_depth': 32, 'subsample_freq': 18, 'colsample_bytree': 0.8929175887054221, 'tweedie_variance_power': 1.243917122555139, 'learning_rate': 0.0030832104600813587, 'num_leaves': 482, 'min_child_samples': 1, 'reg_alpha': 1.0021701468837598, 'reg_lambda': 0.02357693369133705, 'min_split_gain': 4.299068627240887e-07, 'min_child_weight': 0.5985681551888836, 'tpi_ngb': 960, 'n_splines': 25}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:44:53,521] Trial 18 finished with value: 0.7184321448292085 and parameters: {'n_estimators': 2073, 'subsample': 0.9067661968151979, 'max_depth': 19, 'subsample_freq': 27, 'colsample_bytree': 0.7793361199754676, 'tweedie_variance_power': 1.448187469079478, 'learning_rate': 0.00031191596089201804, 'num_leaves': 338, 'min_child_samples': 14, 'reg_alpha': 0.19166299607213727, 'reg_lambda': 0.00010939958157985535, 'min_split_gain': 1.897844442653641e-07, 'min_child_weight': 8.826346952329693, 'tpi_ngb': 240, 'n_splines': 17}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:45:13,219] Trial 19 finished with value: 0.714876535568006 and parameters: {'n_estimators': 1176, 'subsample': 0.7070865079546627, 'max_depth': 27, 'subsample_freq': 27, 'colsample_bytree': 0.6609240387580557, 'tweedie_variance_power': 1.6298420939617968, 'learning_rate': 0.005465652986864004, 'num_leaves': 687, 'min_child_samples': 39, 'reg_alpha': 0.030144653281976436, 'reg_lambda': 0.11819859124637336, 'min_split_gain': 9.589319087216265e-07, 'min_child_weight': 0.1877820180293442, 'tpi_ngb': 60, 'n_splines': 21}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:45:21,939] Trial 20 finished with value: 0.722072727240382 and parameters: {'n_estimators': 463, 'subsample': 0.5952832427938892, 'max_depth': 34, 'subsample_freq': 17, 'colsample_bytree': 0.7678059177571838, 'tweedie_variance_power': 1.5591477658328277, 'learning_rate': 0.0007824715153820662, 'num_leaves': 997, 'min_child_samples': 7, 'reg_alpha': 1.0652633167504346, 'reg_lambda': 0.0006580314309091081, 'min_split_gain': 4.876801145369917e-08, 'min_child_weight': 0.012805884144926675, 'tpi_ngb': 120, 'n_splines': 27}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:45:31,773] Trial 21 finished with value: 0.7138720341312169 and parameters: {'n_estimators': 474, 'subsample': 0.5684949806393831, 'max_depth': 34, 'subsample_freq': 18, 'colsample_bytree': 0.7450135698521573, 'tweedie_variance_power': 1.55873743285121, 'learning_rate': 0.0009887216164337573, 'num_leaves': 987, 'min_child_samples': 7, 'reg_alpha': 0.7882431711914526, 'reg_lambda': 0.0007054862737021904, 'min_split_gain': 4.3329609164740466e-08, 'min_child_weight': 0.011666306234898078, 'tpi_ngb': 120, 'n_splines': 28}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:45:35,725] Trial 22 finished with value: 0.7210091843925713 and parameters: {'n_estimators': 291, 'subsample': 0.6486054630156859, 'max_depth': 27, 'subsample_freq': 24, 'colsample_bytree': 0.8870687536023898, 'tweedie_variance_power': 1.7081240678721898, 'learning_rate': 0.0004570673832903033, 'num_leaves': 876, 'min_child_samples': 17, 'reg_alpha': 2.0174530678478657, 'reg_lambda': 0.0004126394792686804, 'min_split_gain': 5.202729780328366e-08, 'min_child_weight': 0.0006759917354751397, 'tpi_ngb': 120, 'n_splines': 26}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:46:40,366] Trial 23 finished with value: 0.7227431577200302 and parameters: {'n_estimators': 2985, 'subsample': 0.6499540561416343, 'max_depth': 39, 'subsample_freq': 23, 'colsample_bytree': 0.7853364017584697, 'tweedie_variance_power': 1.7342288025407515, 'learning_rate': 0.001377620024134092, 'num_leaves': 858, 'min_child_samples': 20, 'reg_alpha': 1.9078804616272977, 'reg_lambda': 0.00029412256532561126, 'min_split_gain': 4.786150556364885e-08, 'min_child_weight': 0.0007350889639089497, 'tpi_ngb': 120, 'n_splines': 26}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:47:45,516] Trial 24 finished with value: 0.6984592326264647 and parameters: {'n_estimators': 2875, 'subsample': 0.6564019870433999, 'max_depth': 39, 'subsample_freq': 16, 'colsample_bytree': 0.7829304657233785, 'tweedie_variance_power': 1.73919581966221, 'learning_rate': 0.004183728171251538, 'num_leaves': 858, 'min_child_samples': 21, 'reg_alpha': 1.5778297154666368, 'reg_lambda': 0.0015267646079986463, 'min_split_gain': 4.9906714362104666e-08, 'min_child_weight': 0.010266679285461747, 'tpi_ngb': 120, 'n_splines': 29}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:48:27,902] Trial 25 finished with value: 0.7168427812787908 and parameters: {'n_estimators': 2282, 'subsample': 0.5988803576812396, 'max_depth': 43, 'subsample_freq': 21, 'colsample_bytree': 0.708099101604223, 'tweedie_variance_power': 1.903665276166194, 'learning_rate': 0.0013290801258762286, 'num_leaves': 991, 'min_child_samples': 28, 'reg_alpha': 0.6179408764933187, 'reg_lambda': 0.0002288918020238018, 'min_split_gain': 3.763875657287013e-08, 'min_child_weight': 0.0005490072637554045, 'tpi_ngb': 120, 'n_splines': 23}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:48:51,931] Trial 26 finished with value: 0.6972662669004867 and parameters: {'n_estimators': 1621, 'subsample': 0.7349395972926268, 'max_depth': 34, 'subsample_freq': 16, 'colsample_bytree': 0.8096875595859699, 'tweedie_variance_power': 1.6312169336095166, 'learning_rate': 0.016371293453634996, 'num_leaves': 857, 'min_child_samples': 35, 'reg_alpha': 8.376692419887002, 'reg_lambda': 0.010516994640339167, 'min_split_gain': 1.447703822775329e-08, 'min_child_weight': 0.00030133418710746076, 'tpi_ngb': 120, 'n_splines': 26}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:49:47,010] Trial 27 finished with value: 0.7165320265467398 and parameters: {'n_estimators': 2855, 'subsample': 0.6677779280335838, 'max_depth': 36, 'subsample_freq': 19, 'colsample_bytree': 0.6520848801617344, 'tweedie_variance_power': 1.7458620325794625, 'learning_rate': 0.0018397155600840677, 'num_leaves': 712, 'min_child_samples': 27, 'reg_alpha': 2.2487681020845205, 'reg_lambda': 0.0012227191458556357, 'min_split_gain': 5.998389310931754e-08, 'min_child_weight': 1.642463555132342e-05, 'tpi_ngb': 120, 'n_splines': 28}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:50:08,596] Trial 28 finished with value: 0.7171232768118152 and parameters: {'n_estimators': 807, 'subsample': 0.797958676089646, 'max_depth': 40, 'subsample_freq': 12, 'colsample_bytree': 0.764627356929308, 'tweedie_variance_power': 1.5757266842461872, 'learning_rate': 0.000874329402308393, 'num_leaves': 909, 'min_child_samples': 6, 'reg_alpha': 1.3971119610915408, 'reg_lambda': 0.0002236647645925483, 'min_split_gain': 1.2984165947086992e-07, 'min_child_weight': 0.0025043733283710793, 'tpi_ngb': 120, 'n_splines': 23}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:50:32,591] Trial 29 finished with value: 0.720516767345579 and parameters: {'n_estimators': 1392, 'subsample': 0.6937175481935584, 'max_depth': 30, 'subsample_freq': 5, 'colsample_bytree': 0.8264619011993815, 'tweedie_variance_power': 1.8424329472293548, 'learning_rate': 0.0006516900602644605, 'num_leaves': 808, 'min_child_samples': 24, 'reg_alpha': 0.1172012346407534, 'reg_lambda': 0.0016525491185250109, 'min_split_gain': 7.766095380199107e-08, 'min_child_weight': 1.2270316235030034, 'tpi_ngb': 240, 'n_splines': 24}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:51:24,437] Trial 30 finished with value: 0.7126709519866558 and parameters: {'n_estimators': 2379, 'subsample': 0.5716940616784054, 'max_depth': 44, 'subsample_freq': 23, 'colsample_bytree': 0.7033551162263447, 'tweedie_variance_power': 1.4749392114285222, 'learning_rate': 0.0030619706863060222, 'num_leaves': 577, 'min_child_samples': 21, 'reg_alpha': 0.17289230544084333, 'reg_lambda': 0.00018626851393593836, 'min_split_gain': 3.328505864703653e-08, 'min_child_weight': 3.599167975466903e-05, 'tpi_ngb': 120, 'n_splines': 30}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:51:28,796] Trial 31 finished with value: 0.7193725316652392 and parameters: {'n_estimators': 256, 'subsample': 0.6307234914490606, 'max_depth': 27, 'subsample_freq': 25, 'colsample_bytree': 0.8907825021423531, 'tweedie_variance_power': 1.6994324985628868, 'learning_rate': 0.0005143120471298762, 'num_leaves': 921, 'min_child_samples': 16, 'reg_alpha': 2.102950203813525, 'reg_lambda': 0.00039593010270397457, 'min_split_gain': 6.167051339382779e-08, 'min_child_weight': 0.00025412012954543784, 'tpi_ngb': 120, 'n_splines': 26}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:51:38,243] Trial 32 finished with value: 0.7099403692168322 and parameters: {'n_estimators': 514, 'subsample': 0.7309253618574569, 'max_depth': 33, 'subsample_freq': 22, 'colsample_bytree': 0.9980591532961322, 'tweedie_variance_power': 1.770461800132528, 'learning_rate': 0.0001920589778151213, 'num_leaves': 853, 'min_child_samples': 10, 'reg_alpha': 0.47318453133285515, 'reg_lambda': 0.0003380547701261484, 'min_split_gain': 1.7722691360030276e-08, 'min_child_weight': 0.0005037591317609914, 'tpi_ngb': 120, 'n_splines': 27}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:51:42,944] Trial 33 finished with value: 0.721288576951773 and parameters: {'n_estimators': 404, 'subsample': 0.6208125503732382, 'max_depth': 36, 'subsample_freq': 20, 'colsample_bytree': 0.9328875679261894, 'tweedie_variance_power': 1.8553284125369538, 'learning_rate': 0.0015456807950331884, 'num_leaves': 873, 'min_child_samples': 18, 'reg_alpha': 4.593393450268517, 'reg_lambda': 0.000858802007335828, 'min_split_gain': 5.069227002071778e-08, 'min_child_weight': 0.00106833071310862, 'tpi_ngb': 120, 'n_splines': 25}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:51:50,029] Trial 34 finished with value: 0.7160864036562996 and parameters: {'n_estimators': 707, 'subsample': 0.5701894476195769, 'max_depth': 37, 'subsample_freq': 17, 'colsample_bytree': 0.9247853158709602, 'tweedie_variance_power': 1.871454108475711, 'learning_rate': 0.0014771451037265324, 'num_leaves': 757, 'min_child_samples': 30, 'reg_alpha': 5.776268872381469, 'reg_lambda': 0.0009715053594995248, 'min_split_gain': 1.092051953531512e-07, 'min_child_weight': 0.005023436817809928, 'tpi_ngb': 480, 'n_splines': 21}. Best is trial 14 with value: 0.7237039100743324.
# [I 2025-01-15 22:52:01,933] Trial 35 finished with value: 0.7240323306578451 and parameters: {'n_estimators': 951, 'subsample': 0.6824427465871207, 'max_depth': 41, 'subsample_freq': 19, 'colsample_bytree': 0.9700014278975855, 'tweedie_variance_power': 1.8030841786699383, 'learning_rate': 0.0009634001492965364, 'num_leaves': 988, 'min_child_samples': 26, 'reg_alpha': 3.035709375169494, 'reg_lambda': 0.002940470332711263, 'min_split_gain': 7.275848639918492e-08, 'min_child_weight': 0.019883629173474866, 'tpi_ngb': 120, 'n_splines': 24}. Best is trial 35 with value: 0.7240323306578451.
# [I 2025-01-15 22:52:15,213] Trial 36 finished with value: 0.6862588017158849 and parameters: {'n_estimators': 986, 'subsample': 0.6970111800832612, 'max_depth': 42, 'subsample_freq': 13, 'colsample_bytree': 0.5047230163662911, 'tweedie_variance_power': 1.794701776432215, 'learning_rate': 0.0009411164051414664, 'num_leaves': 984, 'min_child_samples': 36, 'reg_alpha': 1.253377132368005, 'reg_lambda': 0.0025231540474751975, 'min_split_gain': 8.800269240088192e-08, 'min_child_weight': 0.023604020808200822, 'tpi_ngb': 60, 'n_splines': 22}. Best is trial 35 with value: 0.7240323306578451.
# [I 2025-01-15 22:52:20,522] Trial 37 finished with value: 0.7157260680257327 and parameters: {'n_estimators': 687, 'subsample': 0.5090755806236614, 'max_depth': 46, 'subsample_freq': 20, 'colsample_bytree': 0.953076728319362, 'tweedie_variance_power': 1.6546682272651976, 'learning_rate': 0.0006760634092103694, 'num_leaves': 823, 'min_child_samples': 41, 'reg_alpha': 2.9667191726759716, 'reg_lambda': 0.012245582914011266, 'min_split_gain': 3.058835214871321e-08, 'min_child_weight': 0.1061293205306555, 'tpi_ngb': 960, 'n_splines': 24}. Best is trial 35 with value: 0.7240323306578451.
# [I 2025-01-15 22:52:37,064] Trial 38 finished with value: 0.720525424055843 and parameters: {'n_estimators': 1007, 'subsample': 0.6835128347809868, 'max_depth': 49, 'subsample_freq': 11, 'colsample_bytree': 0.6183646999307637, 'tweedie_variance_power': 1.5927929218331354, 'learning_rate': 0.0022923487690775677, 'num_leaves': 935, 'min_child_samples': 24, 'reg_alpha': 0.7401807601787154, 'reg_lambda': 0.004653546865661502, 'min_split_gain': 1.6963973089745984e-07, 'min_child_weight': 0.0050729395376262944, 'tpi_ngb': 120, 'n_splines': 20}. Best is trial 35 with value: 0.7240323306578451.
# [I 2025-01-15 22:53:04,184] Trial 39 finished with value: 0.7183729503072466 and parameters: {'n_estimators': 1283, 'subsample': 0.9277467076481993, 'max_depth': 47, 'subsample_freq': 22, 'colsample_bytree': 0.8534986738006959, 'tweedie_variance_power': 1.5329900864298616, 'learning_rate': 0.0010953337398397957, 'num_leaves': 749, 'min_child_samples': 12, 'reg_alpha': 2.7208472641182473, 'reg_lambda': 0.00015237680063375308, 'min_split_gain': 6.815723689385968e-08, 'min_child_weight': 0.017886766263001827, 'tpi_ngb': 240, 'n_splines': 22}. Best is trial 35 with value: 0.7240323306578451.
# [I 2025-01-15 22:53:30,417] Trial 40 finished with value: 0.7144230259744786 and parameters: {'n_estimators': 1575, 'subsample': 0.767628570299086, 'max_depth': 39, 'subsample_freq': 15, 'colsample_bytree': 0.7330974859074525, 'tweedie_variance_power': 1.723624334979237, 'learning_rate': 0.004204459785830357, 'num_leaves': 958, 'min_child_samples': 32, 'reg_alpha': 4.591137436541237, 'reg_lambda': 0.0005462212879025648, 'min_split_gain': 9.205783633022246e-08, 'min_child_weight': 0.06150607440299265, 'tpi_ngb': 120, 'n_splines': 28}. Best is trial 35 with value: 0.7240323306578451.
# [I 2025-01-15 22:53:34,651] Trial 41 finished with value: 0.7197237796820056 and parameters: {'n_estimators': 461, 'subsample': 0.6083705271879983, 'max_depth': 35, 'subsample_freq': 20, 'colsample_bytree': 0.9662793354243121, 'tweedie_variance_power': 1.8447232020094626, 'learning_rate': 0.0007261408616072496, 'num_leaves': 889, 'min_child_samples': 26, 'reg_alpha': 5.766356286672584, 'reg_lambda': 0.0008050453250883055, 'min_split_gain': 3.993749067103031e-08, 'min_child_weight': 0.0010532923335944042, 'tpi_ngb': 120, 'n_splines': 25}. Best is trial 35 with value: 0.7240323306578451.
# [I 2025-01-15 22:53:39,296] Trial 42 finished with value: 0.7233119670236067 and parameters: {'n_estimators': 419, 'subsample': 0.638946338490591, 'max_depth': 32, 'subsample_freq': 19, 'colsample_bytree': 0.9182545226363986, 'tweedie_variance_power': 1.7857665673387144, 'learning_rate': 0.0014550800090128164, 'num_leaves': 1000, 'min_child_samples': 20, 'reg_alpha': 4.030078605917421, 'reg_lambda': 0.0016547002064643942, 'min_split_gain': 2.09605358962857e-08, 'min_child_weight': 0.0001822437836589733, 'tpi_ngb': 120, 'n_splines': 25}. Best is trial 35 with value: 0.7240323306578451.
# [I 2025-01-15 22:54:22,256] Trial 43 finished with value: 0.7265164123819646 and parameters: {'n_estimators': 2684, 'subsample': 0.5511098486565753, 'max_depth': 32, 'subsample_freq': 18, 'colsample_bytree': 0.9745433870569397, 'tweedie_variance_power': 1.7850416625016847, 'learning_rate': 0.00044364124253307055, 'num_leaves': 999, 'min_child_samples': 20, 'reg_alpha': 1.010887955200023, 'reg_lambda': 0.002232716139382497, 'min_split_gain': 2.0164878889560314e-08, 'min_child_weight': 3.771911996840014e-05, 'tpi_ngb': 120, 'n_splines': 26}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:55:01,700] Trial 44 finished with value: 0.7157467126937427 and parameters: {'n_estimators': 2714, 'subsample': 0.5418769294028821, 'max_depth': 31, 'subsample_freq': 22, 'colsample_bytree': 0.9630822830854309, 'tweedie_variance_power': 1.807217730684779, 'learning_rate': 0.00040500277334523947, 'num_leaves': 946, 'min_child_samples': 21, 'reg_alpha': 3.470923869327545, 'reg_lambda': 0.00704178233512314, 'min_split_gain': 1.014609415757215e-08, 'min_child_weight': 5.415814157476973e-05, 'tpi_ngb': 1920, 'n_splines': 22}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:56:06,289] Trial 45 finished with value: 0.7077384030525428 and parameters: {'n_estimators': 2967, 'subsample': 0.733448631229038, 'max_depth': 29, 'subsample_freq': 24, 'colsample_bytree': 0.9931650013122165, 'tweedie_variance_power': 1.7740420938534216, 'learning_rate': 0.0023692359924529084, 'num_leaves': 797, 'min_child_samples': 20, 'reg_alpha': 1.5905684025136422, 'reg_lambda': 0.055227937521060866, 'min_split_gain': 2.1488662496588143e-08, 'min_child_weight': 0.00017612742944782457, 'tpi_ngb': 480, 'n_splines': 24}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:56:39,192] Trial 46 finished with value: 0.7252136499606328 and parameters: {'n_estimators': 2626, 'subsample': 0.6330626901595241, 'max_depth': 38, 'subsample_freq': 28, 'colsample_bytree': 0.9196539960091104, 'tweedie_variance_power': 1.6708540580459084, 'learning_rate': 0.0002519575977019314, 'num_leaves': 948, 'min_child_samples': 23, 'reg_alpha': 6.323678328891356, 'reg_lambda': 0.002444549823350243, 'min_split_gain': 1.7975344366414807e-08, 'min_child_weight': 2.9832961787158943e-05, 'tpi_ngb': 120, 'n_splines': 19}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:57:15,537] Trial 47 finished with value: 0.7147832972400178 and parameters: {'n_estimators': 2634, 'subsample': 0.6303319081657391, 'max_depth': 37, 'subsample_freq': 28, 'colsample_bytree': 0.9095766385203219, 'tweedie_variance_power': 1.9419236464321645, 'learning_rate': 0.00011251390595880373, 'num_leaves': 944, 'min_child_samples': 25, 'reg_alpha': 6.448486306984156, 'reg_lambda': 0.0023601520031477255, 'min_split_gain': 1.7637789361321145e-08, 'min_child_weight': 2.8339104388699132e-05, 'tpi_ngb': 120, 'n_splines': 19}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:57:32,820] Trial 48 finished with value: 0.7010466693149608 and parameters: {'n_estimators': 2432, 'subsample': 0.5566886228144549, 'max_depth': 32, 'subsample_freq': 25, 'colsample_bytree': 0.9755399535456598, 'tweedie_variance_power': 1.8907223814286467, 'learning_rate': 0.0002403034181435079, 'num_leaves': 76, 'min_child_samples': 23, 'reg_alpha': 8.945410061364774, 'reg_lambda': 0.004849598632683403, 'min_split_gain': 1.2530083327415372e-08, 'min_child_weight': 0.00011745178936673037, 'tpi_ngb': 30, 'n_splines': 16}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:58:02,124] Trial 49 finished with value: 0.7056952615265942 and parameters: {'n_estimators': 2088, 'subsample': 0.8467012088739075, 'max_depth': 28, 'subsample_freq': 29, 'colsample_bytree': 0.9324634429438009, 'tweedie_variance_power': 1.6746078915286184, 'learning_rate': 0.0003388347912550248, 'num_leaves': 904, 'min_child_samples': 31, 'reg_alpha': 3.9491524842955545, 'reg_lambda': 0.009401550929527448, 'min_split_gain': 2.5173872633244852e-08, 'min_child_weight': 1.0742815684856396e-05, 'tpi_ngb': 1920, 'n_splines': 19}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:58:40,549] Trial 50 finished with value: 0.7139957364693815 and parameters: {'n_estimators': 2741, 'subsample': 0.6733439487845398, 'max_depth': 25, 'subsample_freq': 26, 'colsample_bytree': 0.9486515289589703, 'tweedie_variance_power': 1.813885959497112, 'learning_rate': 0.00018222810364266177, 'num_leaves': 389, 'min_child_samples': 35, 'reg_alpha': 0.024894104992788105, 'reg_lambda': 0.014665728018140207, 'min_split_gain': 4.0833119865888e-07, 'min_child_weight': 7.130559589460427e-05, 'tpi_ngb': 960, 'n_splines': 23}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:59:30,708] Trial 51 finished with value: 0.7240325736274811 and parameters: {'n_estimators': 2552, 'subsample': 0.7891813372678268, 'max_depth': 38, 'subsample_freq': 19, 'colsample_bytree': 0.8336176479600195, 'tweedie_variance_power': 1.7593052087438368, 'learning_rate': 0.000531928691516685, 'num_leaves': 827, 'min_child_samples': 27, 'reg_alpha': 0.055828787965524096, 'reg_lambda': 0.0017132215963235329, 'min_split_gain': 1.8835281022109065e-08, 'min_child_weight': 2.387836817513568e-05, 'tpi_ngb': 120, 'n_splines': 25}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 22:59:57,635] Trial 52 finished with value: 0.7261144082039104 and parameters: {'n_estimators': 1814, 'subsample': 0.80170091748921, 'max_depth': 45, 'subsample_freq': 18, 'colsample_bytree': 0.8719213675463209, 'tweedie_variance_power': 1.7703297118113224, 'learning_rate': 0.0005316866393310042, 'num_leaves': 963, 'min_child_samples': 49, 'reg_alpha': 0.05686037930203582, 'reg_lambda': 0.0018754559802555393, 'min_split_gain': 1.871519272757007e-08, 'min_child_weight': 2.2955871070319055e-05, 'tpi_ngb': 120, 'n_splines': 25}. Best is trial 43 with value: 0.7265164123819646.
# [I 2025-01-15 23:00:24,639] Trial 53 finished with value: 0.727258292394181 and parameters: {'n_estimators': 1858, 'subsample': 0.787503639611654, 'max_depth': 45, 'subsample_freq': 14, 'colsample_bytree': 0.8358918767730826, 'tweedie_variance_power': 1.6670596347362685, 'learning_rate': 0.0005068486402821181, 'num_leaves': 948, 'min_child_samples': 48, 'reg_alpha': 0.062172925288966216, 'reg_lambda': 0.03503921770744462, 'min_split_gain': 1.6432960728409867e-08, 'min_child_weight': 1.8933005706982717e-05, 'tpi_ngb': 120, 'n_splines': 23}. Best is trial 53 with value: 0.727258292394181.
# [I 2025-01-15 23:00:50,430] Trial 54 finished with value: 0.7271499751104527 and parameters: {'n_estimators': 1822, 'subsample': 0.7923305037153967, 'max_depth': 45, 'subsample_freq': 15, 'colsample_bytree': 0.8640060364681508, 'tweedie_variance_power': 1.656142558489768, 'learning_rate': 0.0005437128680961744, 'num_leaves': 944, 'min_child_samples': 50, 'reg_alpha': 0.05695526280024885, 'reg_lambda': 0.028374172178376986, 'min_split_gain': 1.6582749416212158e-08, 'min_child_weight': 2.1804598620543702e-05, 'tpi_ngb': 120, 'n_splines': 19}. Best is trial 53 with value: 0.727258292394181.
# [I 2025-01-15 23:01:16,224] Trial 55 finished with value: 0.7277971335077825 and parameters: {'n_estimators': 1795, 'subsample': 0.793224337419359, 'max_depth': 46, 'subsample_freq': 14, 'colsample_bytree': 0.8356899472160177, 'tweedie_variance_power': 1.6944267934727033, 'learning_rate': 0.0005242410873621399, 'num_leaves': 943, 'min_child_samples': 49, 'reg_alpha': 0.05757909380980792, 'reg_lambda': 0.050333164343805, 'min_split_gain': 1.7010142394774287e-08, 'min_child_weight': 2.3297747127634805e-05, 'tpi_ngb': 60, 'n_splines': 19}. Best is trial 55 with value: 0.7277971335077825.
# [I 2025-01-15 23:01:44,366] Trial 56 finished with value: 0.7229845293347662 and parameters: {'n_estimators': 1883, 'subsample': 0.8252262320463464, 'max_depth': 45, 'subsample_freq': 14, 'colsample_bytree': 0.8633762091220588, 'tweedie_variance_power': 1.665735352562244, 'learning_rate': 0.00013142764785476423, 'num_leaves': 953, 'min_child_samples': 50, 'reg_alpha': 0.06782145172066928, 'reg_lambda': 0.04170033151498335, 'min_split_gain': 1.4509683969943374e-08, 'min_child_weight': 4.6107879920255404e-05, 'tpi_ngb': 60, 'n_splines': 16}. Best is trial 55 with value: 0.7277971335077825.
# [I 2025-01-15 23:02:19,368] Trial 57 finished with value: 0.5693738809361568 and parameters: {'n_estimators': 1737, 'subsample': 0.804321901702311, 'max_depth': 48, 'subsample_freq': 10, 'colsample_bytree': 0.8784728469933494, 'tweedie_variance_power': 1.6971978482188745, 'learning_rate': 0.08191987735926455, 'num_leaves': 898, 'min_child_samples': 49, 'reg_alpha': 0.04653976735839771, 'reg_lambda': 0.1106422753536476, 'min_split_gain': 1.095414034221849e-08, 'min_child_weight': 1.9924099687294885e-05, 'tpi_ngb': 60, 'n_splines': 18}. Best is trial 55 with value: 0.7277971335077825.
# [I 2025-01-15 23:02:50,252] Trial 58 finished with value: 0.7274691701143526 and parameters: {'n_estimators': 2189, 'subsample': 0.7523282977093222, 'max_depth': 50, 'subsample_freq': 7, 'colsample_bytree': 0.8407219550569953, 'tweedie_variance_power': 1.596351285636849, 'learning_rate': 0.0002788044414164313, 'num_leaves': 278, 'min_child_samples': 47, 'reg_alpha': 0.10100247414613768, 'reg_lambda': 0.3311372357906683, 'min_split_gain': 1.4592858824851677e-08, 'min_child_weight': 7.491533501924876e-05, 'tpi_ngb': 60, 'n_splines': 19}. Best is trial 55 with value: 0.7277971335077825.
# [I 2025-01-15 23:03:16,221] Trial 59 finished with value: 0.7280233210662728 and parameters: {'n_estimators': 1922, 'subsample': 0.7565691201218783, 'max_depth': 49, 'subsample_freq': 6, 'colsample_bytree': 0.8407948944258521, 'tweedie_variance_power': 1.6101381626284381, 'learning_rate': 0.00035626552598241466, 'num_leaves': 245, 'min_child_samples': 47, 'reg_alpha': 0.0802722247953919, 'reg_lambda': 0.3422554975665294, 'min_split_gain': 1.441206754226375e-08, 'min_child_weight': 8.773485167838443e-05, 'tpi_ngb': 60, 'n_splines': 18}. Best is trial 59 with value: 0.7280233210662728.
# [I 2025-01-15 23:03:46,982] Trial 60 finished with value: 0.7278214406040233 and parameters: {'n_estimators': 2251, 'subsample': 0.7445003516426667, 'max_depth': 49, 'subsample_freq': 3, 'colsample_bytree': 0.8123681920305706, 'tweedie_variance_power': 1.5997545423918855, 'learning_rate': 0.0003298970289262477, 'num_leaves': 222, 'min_child_samples': 46, 'reg_alpha': 0.09965359905592444, 'reg_lambda': 0.37224965814420075, 'min_split_gain': 1.516544627018128e-08, 'min_child_weight': 9.372127083552139e-05, 'tpi_ngb': 60, 'n_splines': 18}. Best is trial 59 with value: 0.7280233210662728.
# [I 2025-01-15 23:04:19,169] Trial 61 finished with value: 0.7282186350659691 and parameters: {'n_estimators': 2224, 'subsample': 0.7514764433397145, 'max_depth': 50, 'subsample_freq': 3, 'colsample_bytree': 0.8332454777026497, 'tweedie_variance_power': 1.6094313855773228, 'learning_rate': 0.0003498980609844684, 'num_leaves': 227, 'min_child_samples': 46, 'reg_alpha': 0.11029525547850055, 'reg_lambda': 0.40820525952988096, 'min_split_gain': 1.3428038455476445e-08, 'min_child_weight': 8.847434537844201e-05, 'tpi_ngb': 60, 'n_splines': 18}. Best is trial 61 with value: 0.7282186350659691.
# [I 2025-01-15 23:04:50,325] Trial 62 finished with value: 0.7282264627233197 and parameters: {'n_estimators': 2227, 'subsample': 0.7497249488439937, 'max_depth': 50, 'subsample_freq': 3, 'colsample_bytree': 0.8428430371377786, 'tweedie_variance_power': 1.607983712014175, 'learning_rate': 0.00032623399423554577, 'num_leaves': 237, 'min_child_samples': 46, 'reg_alpha': 0.11024635153589771, 'reg_lambda': 0.5129283383458584, 'min_split_gain': 1.4580637709467104e-08, 'min_child_weight': 7.977869321100759e-05, 'tpi_ngb': 60, 'n_splines': 18}. Best is trial 62 with value: 0.7282264627233197.
# [I 2025-01-15 23:05:20,968] Trial 63 finished with value: 0.7282661858371604 and parameters: {'n_estimators': 2199, 'subsample': 0.7559779344809147, 'max_depth': 50, 'subsample_freq': 3, 'colsample_bytree': 0.8409509915056715, 'tweedie_variance_power': 1.6125826193174764, 'learning_rate': 0.0003315749630443509, 'num_leaves': 232, 'min_child_samples': 46, 'reg_alpha': 0.09888236290300641, 'reg_lambda': 0.48853837468531924, 'min_split_gain': 1.376834990430332e-08, 'min_child_weight': 8.355854390371657e-05, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 63 with value: 0.7282661858371604.
# [I 2025-01-15 23:05:52,039] Trial 64 finished with value: 0.7282780501546 and parameters: {'n_estimators': 2214, 'subsample': 0.7545902110055591, 'max_depth': 50, 'subsample_freq': 3, 'colsample_bytree': 0.8119026185582708, 'tweedie_variance_power': 1.6007314513911406, 'learning_rate': 0.0003239993004883485, 'num_leaves': 221, 'min_child_samples': 43, 'reg_alpha': 0.0899070177957079, 'reg_lambda': 0.5662161299139076, 'min_split_gain': 1.2419442243028811e-08, 'min_child_weight': 9.100280737453861e-05, 'tpi_ngb': 60, 'n_splines': 13}. Best is trial 64 with value: 0.7282780501546.
# [I 2025-01-15 23:06:16,845] Trial 65 finished with value: 0.7265358378303988 and parameters: {'n_estimators': 1990, 'subsample': 0.7191902723567212, 'max_depth': 48, 'subsample_freq': 2, 'colsample_bytree': 0.8113473592876262, 'tweedie_variance_power': 1.5378924699978025, 'learning_rate': 0.00020832871314067407, 'num_leaves': 218, 'min_child_samples': 44, 'reg_alpha': 0.09298758005321951, 'reg_lambda': 2.679239715727088, 'min_split_gain': 1.2760934737687077e-08, 'min_child_weight': 0.00012317867175118836, 'tpi_ngb': 60, 'n_splines': 11}. Best is trial 64 with value: 0.7282780501546.
# [I 2025-01-15 23:06:44,135] Trial 66 finished with value: 0.7294374885860765 and parameters: {'n_estimators': 2228, 'subsample': 0.7561818310253893, 'max_depth': 50, 'subsample_freq': 2, 'colsample_bytree': 0.7982038196212645, 'tweedie_variance_power': 1.503528377172269, 'learning_rate': 0.00034639625963757913, 'num_leaves': 160, 'min_child_samples': 43, 'reg_alpha': 0.1480545797664594, 'reg_lambda': 0.5816706566583169, 'min_split_gain': 1.2080986139378254e-08, 'min_child_weight': 0.0003113498189450866, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:07:09,689] Trial 67 finished with value: 0.7289978646472626 and parameters: {'n_estimators': 2271, 'subsample': 0.751261286480367, 'max_depth': 50, 'subsample_freq': 2, 'colsample_bytree': 0.8131429281345032, 'tweedie_variance_power': 1.4881443921436794, 'learning_rate': 0.0003419205622639915, 'num_leaves': 129, 'min_child_samples': 42, 'reg_alpha': 0.1496943218489881, 'reg_lambda': 0.7197016984642141, 'min_split_gain': 1.1151522914061923e-08, 'min_child_weight': 0.00031572413132397164, 'tpi_ngb': 60, 'n_splines': 13}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:07:31,197] Trial 68 finished with value: 0.7214980011641713 and parameters: {'n_estimators': 2391, 'subsample': 0.7153279114821891, 'max_depth': 50, 'subsample_freq': 0, 'colsample_bytree': 0.7657768498624903, 'tweedie_variance_power': 1.491947340411615, 'learning_rate': 0.00014807913469548503, 'num_leaves': 133, 'min_child_samples': 40, 'reg_alpha': 0.1480270563176176, 'reg_lambda': 1.783396962780793, 'min_split_gain': 1.1527506942931025e-08, 'min_child_weight': 0.0002608220155869961, 'tpi_ngb': 60, 'n_splines': 12}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:07:55,527] Trial 69 finished with value: 0.7293969085255758 and parameters: {'n_estimators': 2144, 'subsample': 0.7699855707156343, 'max_depth': 48, 'subsample_freq': 4, 'colsample_bytree': 0.7929976973390053, 'tweedie_variance_power': 1.3498024428939017, 'learning_rate': 0.0003802111303730472, 'num_leaves': 141, 'min_child_samples': 42, 'reg_alpha': 0.24002845633194678, 'reg_lambda': 0.7240733536220624, 'min_split_gain': 1.0218827821175847e-08, 'min_child_weight': 0.0003494171448455138, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:08:20,754] Trial 70 finished with value: 0.7271558517611793 and parameters: {'n_estimators': 2138, 'subsample': 0.7690315998906421, 'max_depth': 47, 'subsample_freq': 4, 'colsample_bytree': 0.791012388053456, 'tweedie_variance_power': 1.3168742621462584, 'learning_rate': 0.00020376695291288537, 'num_leaves': 146, 'min_child_samples': 43, 'reg_alpha': 0.25754695648987963, 'reg_lambda': 0.7823205509493796, 'min_split_gain': 1.0088146690945335e-08, 'min_child_weight': 0.00038226210170580325, 'tpi_ngb': 60, 'n_splines': 13}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:08:47,559] Trial 71 finished with value: 0.7290993003794862 and parameters: {'n_estimators': 1997, 'subsample': 0.7518744373134459, 'max_depth': 50, 'subsample_freq': 1, 'colsample_bytree': 0.8206857912817694, 'tweedie_variance_power': 1.2082540365530576, 'learning_rate': 0.0003798873446609303, 'num_leaves': 300, 'min_child_samples': 42, 'reg_alpha': 0.13416416456275188, 'reg_lambda': 0.5811034695747721, 'min_split_gain': 1.2940545977297106e-08, 'min_child_weight': 0.00017107049307138136, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:09:20,148] Trial 72 finished with value: 0.728770153788594 and parameters: {'n_estimators': 2303, 'subsample': 0.7777816052869433, 'max_depth': 48, 'subsample_freq': 1, 'colsample_bytree': 0.8171544144804445, 'tweedie_variance_power': 1.1423244601563318, 'learning_rate': 0.00029207053860155345, 'num_leaves': 329, 'min_child_samples': 42, 'reg_alpha': 0.14301053766271446, 'reg_lambda': 0.5226053085255008, 'min_split_gain': 1.2195313963517065e-08, 'min_child_weight': 0.00019114029496760204, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:09:53,159] Trial 73 finished with value: 0.7287635904834774 and parameters: {'n_estimators': 2318, 'subsample': 0.7730366451182875, 'max_depth': 48, 'subsample_freq': 1, 'colsample_bytree': 0.7526909017648772, 'tweedie_variance_power': 1.1247773043086275, 'learning_rate': 0.00028024584919908137, 'num_leaves': 306, 'min_child_samples': 42, 'reg_alpha': 0.21459435964836368, 'reg_lambda': 0.569323736025986, 'min_split_gain': 1.1746195864492631e-08, 'min_child_weight': 0.00017174681579164481, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:10:27,116] Trial 74 finished with value: 0.7283387966461925 and parameters: {'n_estimators': 2316, 'subsample': 0.8163219674871949, 'max_depth': 48, 'subsample_freq': 1, 'colsample_bytree': 0.7506567842851877, 'tweedie_variance_power': 1.1088712567790098, 'learning_rate': 0.0002473172105429327, 'num_leaves': 350, 'min_child_samples': 42, 'reg_alpha': 0.212659613455417, 'reg_lambda': 0.21002676364796996, 'min_split_gain': 1.084283299492819e-08, 'min_child_weight': 0.0001847045041820848, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:11:03,337] Trial 75 finished with value: 0.721831017042089 and parameters: {'n_estimators': 2321, 'subsample': 0.828942014698336, 'max_depth': 48, 'subsample_freq': 1, 'colsample_bytree': 0.7296904272913264, 'tweedie_variance_power': 1.1148348300324828, 'learning_rate': 0.00023756491624552192, 'num_leaves': 317, 'min_child_samples': 42, 'reg_alpha': 0.23224329129899457, 'reg_lambda': 0.23056487099645234, 'min_split_gain': 1.1533606988654281e-08, 'min_child_weight': 0.00042838178807777315, 'tpi_ngb': 60, 'n_splines': 14}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:11:39,810] Trial 76 finished with value: 0.720346543293641 and parameters: {'n_estimators': 2460, 'subsample': 0.7784033983556429, 'max_depth': 47, 'subsample_freq': 1, 'colsample_bytree': 0.7492436351579602, 'tweedie_variance_power': 1.1891562576524328, 'learning_rate': 0.00015455673570328914, 'num_leaves': 417, 'min_child_samples': 39, 'reg_alpha': 0.3488760318407752, 'reg_lambda': 1.4221170331135171, 'min_split_gain': 1.1390157397440416e-08, 'min_child_weight': 0.00021144509508749202, 'tpi_ngb': 60, 'n_splines': 13}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:11:55,659] Trial 77 finished with value: 0.7257834385646944 and parameters: {'n_estimators': 2054, 'subsample': 0.8127941811898086, 'max_depth': 43, 'subsample_freq': 0, 'colsample_bytree': 0.7732176999960174, 'tweedie_variance_power': 1.1992886963565135, 'learning_rate': 0.00041471872340498263, 'num_leaves': 85, 'min_child_samples': 37, 'reg_alpha': 0.14167107237778762, 'reg_lambda': 3.8104048686805627, 'min_split_gain': 1.0040188338701663e-08, 'min_child_weight': 0.002055388138481453, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:12:34,919] Trial 78 finished with value: 0.7265681427004822 and parameters: {'n_estimators': 2338, 'subsample': 0.8589047322990958, 'max_depth': 48, 'subsample_freq': 2, 'colsample_bytree': 0.7950837161727584, 'tweedie_variance_power': 1.1016910027424904, 'learning_rate': 0.00028206040611104144, 'num_leaves': 335, 'min_child_samples': 38, 'reg_alpha': 0.19444378147436914, 'reg_lambda': 1.1285574906464895, 'min_split_gain': 1.1792891279183888e-08, 'min_child_weight': 0.0001630891003753277, 'tpi_ngb': 60, 'n_splines': 15}. Best is trial 66 with value: 0.7294374885860765.
# [I 2025-01-15 23:13:11,489] Trial 79 finished with value: 0.6929059400645392 and parameters: {'n_estimators': 2498, 'subsample': 0.77586703351443, 'max_depth': 15, 'subsample_freq': 5, 'colsample_bytree': 0.8179167827924345, 'tweedie_variance_power': 1.1532931447864758, 'learning_rate': 0.012096606801067639, 'num_leaves': 288, 'min_child_samples': 41, 'reg_alpha': 0.2266371477214829, 'reg_lambda': 0.1990601615664056, 'min_split_gain': 2.8042944123418342e-08, 'min_child_weight': 0.0006540367441599628, 'tpi_ngb': 60, 'n_splines': 13}. Best is trial 66 with value: 0.7294374885860765.
# ...
# [I 2025-01-15 23:27:19,302] Trial 124 finished with value: 0.7312486908065818 and parameters: {'n_estimators': 1170, 'subsample': 0.9708673739708804, 'max_depth': 36, 'subsample_freq': 12, 'colsample_bytree': 0.921934633234486, 'tweedie_variance_power': 1.438719912777908, 'learning_rate': 0.004052856238587688, 'num_leaves': 40, 'min_child_samples': 49, 'reg_alpha': 0.4358235865681377, 'reg_lambda': 7.722513532352546, 'min_split_gain': 3.760948435275103e-08, 'min_child_weight': 0.003438704489621204, 'tpi_ngb': 60, 'n_splines': 12}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:27:25,616] Trial 125 finished with value: 0.7263051584582711 and parameters: {'n_estimators': 1206, 'subsample': 0.9655864551514395, 'max_depth': 36, 'subsample_freq': 12, 'colsample_bytree': 0.9291952114427204, 'tweedie_variance_power': 1.4421487690501225, 'learning_rate': 0.0068963051724173835, 'num_leaves': 41, 'min_child_samples': 49, 'reg_alpha': 0.4627053242575457, 'reg_lambda': 7.927837566071022, 'min_split_gain': 3.6529290474653383e-08, 'min_child_weight': 0.004031142795351475, 'tpi_ngb': 60, 'n_splines': 12}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:27:32,494] Trial 126 finished with value: 0.7300708900838695 and parameters: {'n_estimators': 1110, 'subsample': 0.9836724263130794, 'max_depth': 35, 'subsample_freq': 13, 'colsample_bytree': 0.9396728082623644, 'tweedie_variance_power': 1.38781410258548, 'learning_rate': 0.003905507144146399, 'num_leaves': 61, 'min_child_samples': 50, 'reg_alpha': 0.35668571084715633, 'reg_lambda': 6.2842816164381565, 'min_split_gain': 3.143793383031058e-08, 'min_child_weight': 0.015540623766188954, 'tpi_ngb': 60, 'n_splines': 10}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:27:37,135] Trial 127 finished with value: 0.7315860770352304 and parameters: {'n_estimators': 857, 'subsample': 0.9545166206515572, 'max_depth': 38, 'subsample_freq': 13, 'colsample_bytree': 0.8878345312642939, 'tweedie_variance_power': 1.3726287406965962, 'learning_rate': 0.00380927184977236, 'num_leaves': 24, 'min_child_samples': 48, 'reg_alpha': 0.42496184802739684, 'reg_lambda': 9.301378515446439, 'min_split_gain': 3.3429031949599996e-08, 'min_child_weight': 0.007178761832992125, 'tpi_ngb': 60, 'n_splines': 11}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:27:41,461] Trial 128 finished with value: 0.7320287786025211 and parameters: {'n_estimators': 905, 'subsample': 0.955774297309365, 'max_depth': 37, 'subsample_freq': 13, 'colsample_bytree': 0.8874534733601066, 'tweedie_variance_power': 1.3757793224762087, 'learning_rate': 0.0035538565857045267, 'num_leaves': 27, 'min_child_samples': 48, 'reg_alpha': 0.30000049061087386, 'reg_lambda': 6.703624000779243, 'min_split_gain': 4.289168947508178e-08, 'min_child_weight': 0.008951674709431008, 'tpi_ngb': 60, 'n_splines': 10}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:27:45,653] Trial 129 finished with value: 0.7270248121527126 and parameters: {'n_estimators': 839, 'subsample': 0.9534753853639426, 'max_depth': 38, 'subsample_freq': 13, 'colsample_bytree': 0.9199395901343054, 'tweedie_variance_power': 1.3693688342950239, 'learning_rate': 0.004413467641413899, 'num_leaves': 29, 'min_child_samples': 49, 'reg_alpha': 0.3152977357946065, 'reg_lambda': 9.82714561165262, 'min_split_gain': 3.4088968472033e-08, 'min_child_weight': 0.009505210776698022, 'tpi_ngb': 30, 'n_splines': 12}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:27:52,193] Trial 130 finished with value: 0.7318499177028888 and parameters: {'n_estimators': 1060, 'subsample': 0.9744724457106224, 'max_depth': 34, 'subsample_freq': 10, 'colsample_bytree': 0.886901287981191, 'tweedie_variance_power': 1.4353179027554424, 'learning_rate': 0.003604401220751444, 'num_leaves': 62, 'min_child_samples': 46, 'reg_alpha': 0.29468838221461247, 'reg_lambda': 6.503541907451012, 'min_split_gain': 2.3931028198567413e-08, 'min_child_weight': 0.005427825970819838, 'tpi_ngb': 240, 'n_splines': 11}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:27:59,001] Trial 131 finished with value: 0.7321581401716764 and parameters: {'n_estimators': 1058, 'subsample': 0.9747166386948268, 'max_depth': 34, 'subsample_freq': 10, 'colsample_bytree': 0.8879459351807444, 'tweedie_variance_power': 1.435221284285223, 'learning_rate': 0.003461791873435989, 'num_leaves': 61, 'min_child_samples': 46, 'reg_alpha': 0.2848941965097986, 'reg_lambda': 6.637102588088, 'min_split_gain': 3.171237108556814e-08, 'min_child_weight': 0.005983534911014221, 'tpi_ngb': 240, 'n_splines': 11}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:28:02,343] Trial 132 finished with value: 0.7303838936041478 and parameters: {'n_estimators': 1015, 'subsample': 0.9793155783708783, 'max_depth': 33, 'subsample_freq': 11, 'colsample_bytree': 0.8897456521240314, 'tweedie_variance_power': 1.4338800397107228, 'learning_rate': 0.0036144302266252807, 'num_leaves': 10, 'min_child_samples': 46, 'reg_alpha': 0.2639560380606926, 'reg_lambda': 6.849639965685705, 'min_split_gain': 4.063736448456258e-08, 'min_child_weight': 0.005932540893872978, 'tpi_ngb': 240, 'n_splines': 10}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:28:08,076] Trial 133 finished with value: 0.7299695992372669 and parameters: {'n_estimators': 905, 'subsample': 0.9684689183295841, 'max_depth': 37, 'subsample_freq': 10, 'colsample_bytree': 0.9165763237846757, 'tweedie_variance_power': 1.3957144783331221, 'learning_rate': 0.0026435193942552677, 'num_leaves': 62, 'min_child_samples': 48, 'reg_alpha': 0.46555498282330815, 'reg_lambda': 4.435716441105146, 'min_split_gain': 2.3667726476990712e-08, 'min_child_weight': 0.0037846065489910295, 'tpi_ngb': 240, 'n_splines': 12}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:28:17,615] Trial 134 finished with value: 0.7255523903449899 and parameters: {'n_estimators': 1201, 'subsample': 0.9891073302076567, 'max_depth': 36, 'subsample_freq': 12, 'colsample_bytree': 0.8685296047389504, 'tweedie_variance_power': 1.4618933224895785, 'learning_rate': 0.005743766895355512, 'num_leaves': 83, 'min_child_samples': 46, 'reg_alpha': 0.2808691129510537, 'reg_lambda': 6.725085652541663, 'min_split_gain': 4.316139268268472e-08, 'min_child_weight': 0.013375492334035231, 'tpi_ngb': 240, 'n_splines': 11}. Best is trial 117 with value: 0.7330548470815973.
# [I 2025-01-15 23:28:22,623] Trial 135 finished with value: 0.7342284309601583 and parameters: {'n_estimators': 1050, 'subsample': 0.9579460535769034, 'max_depth': 34, 'subsample_freq': 10, 'colsample_bytree': 0.9052564529857148, 'tweedie_variance_power': 1.422941182920724, 'learning_rate': 0.0033666390730187905, 'num_leaves': 32, 'min_child_samples': 47, 'reg_alpha': 0.3486332366637274, 'reg_lambda': 4.194771621282867, 'min_split_gain': 5.604190555457293e-08, 'min_child_weight': 0.02651945428366146, 'tpi_ngb': 240, 'n_splines': 10}. Best is trial 135 with value: 0.7342284309601583.
# [I 2025-01-15 23:28:27,578] Trial 136 finished with value: 0.7344504651970449 and parameters: {'n_estimators': 1043, 'subsample': 0.9561254036882516, 'max_depth': 34, 'subsample_freq': 10, 'colsample_bytree': 0.9063299538031513, 'tweedie_variance_power': 1.426550730837315, 'learning_rate': 0.003294144035916002, 'num_leaves': 31, 'min_child_samples': 47, 'reg_alpha': 0.36053807190682563, 'reg_lambda': 4.919647263277119, 'min_split_gain': 4.6675940276224e-08, 'min_child_weight': 0.03521439039366259, 'tpi_ngb': 240, 'n_splines': 10}. Best is trial 136 with value: 0.7344504651970449.
# [I 2025-01-15 23:28:33,010] Trial 137 finished with value: 0.733158400672228 and parameters: {'n_estimators': 1076, 'subsample': 0.9590627758165343, 'max_depth': 34, 'subsample_freq': 13, 'colsample_bytree': 0.903134810856359, 'tweedie_variance_power': 1.4288356565586946, 'learning_rate': 0.003505582868515771, 'num_leaves': 35, 'min_child_samples': 47, 'reg_alpha': 0.3603640953507526, 'reg_lambda': 4.301163760326077, 'min_split_gain': 5.931095488253798e-08, 'min_child_weight': 0.031974168050397815, 'tpi_ngb': 240, 'n_splines': 10}. Best is trial 136 with value: 0.7344504651970449.
# [I 2025-01-15 23:28:38,301] Trial 138 finished with value: 0.7300706303932178 and parameters: {'n_estimators': 1059, 'subsample': 0.9556822275053644, 'max_depth': 34, 'subsample_freq': 13, 'colsample_bytree': 0.9234071117277542, 'tweedie_variance_power': 1.4247356094512802, 'learning_rate': 0.00479030270339031, 'num_leaves': 39, 'min_child_samples': 47, 'reg_alpha': 0.35730114507453686, 'reg_lambda': 4.569092488381126, 'min_split_gain': 5.646184067615465e-08, 'min_child_weight': 0.033588418799232106, 'tpi_ngb': 240, 'n_splines': 10}. Best is trial 136 with value: 0.7344504651970449.
# [I 2025-01-15 23:28:43,637] Trial 139 finished with value: 0.7305158767628973 and parameters: {'n_estimators': 947, 'subsample': 0.919643779989189, 'max_depth': 33, 'subsample_freq': 13, 'colsample_bytree': 0.9343642907795211, 'tweedie_variance_power': 1.4649162747432787, 'learning_rate': 0.003410896108218202, 'num_leaves': 54, 'min_child_samples': 48, 'reg_alpha': 0.2727486240123895, 'reg_lambda': 9.491238944236578, 'min_split_gain': 3.555510964327373e-08, 'min_child_weight': 0.06554473873681575, 'tpi_ngb': 240, 'n_splines': 10}. Best is trial 136 with value: 0.7344504651970449.
# [I 2025-01-15 23:28:48,656] Trial 140 finished with value: 0.7335545403143069 and parameters: {'n_estimators': 1138, 'subsample': 0.9765237401956954, 'max_depth': 35, 'subsample_freq': 15, 'colsample_bytree': 0.8985780902711902, 'tweedie_variance_power': 1.3996697996536542, 'learning_rate': 0.0029679992857485613, 'num_leaves': 28, 'min_child_samples': 46, 'reg_alpha': 0.30142523034305424, 'reg_lambda': 4.102434537326954, 'min_split_gain': 4.6738541305966355e-08, 'min_child_weight': 0.02726683945919214, 'tpi_ngb': 240, 'n_splines': 12}. Best is trial 136 with value: 0.7344504651970449.
# [I 2025-01-15 23:28:53,219] Trial 141 finished with value: 0.7347756890534961 and parameters: {'n_estimators': 1149, 'subsample': 0.9761096708362259, 'max_depth': 34, 'subsample_freq': 16, 'colsample_bytree': 0.9473248299715323, 'tweedie_variance_power': 1.407663068135031, 'learning_rate': 0.003065732381164207, 'num_leaves': 23, 'min_child_samples': 46, 'reg_alpha': 0.30629005023048184, 'reg_lambda': 5.2217107812405485, 'min_split_gain': 4.752879344329507e-08, 'min_child_weight': 0.026347269517283937, 'tpi_ngb': 240, 'n_splines': 12}. Best is trial 141 with value: 0.7347756890534961.
# [I 2025-01-15 23:28:57,038] Trial 142 finished with value: 0.7329912262046473 and parameters: {'n_estimators': 840, 'subsample': 0.975722741745858, 'max_depth': 34, 'subsample_freq': 16, 'colsample_bytree': 0.9529449711451046, 'tweedie_variance_power': 1.3733854707375535, 'learning_rate': 0.0030470158706946806, 'num_leaves': 26, 'min_child_samples': 46, 'reg_alpha': 0.34295928649657687, 'reg_lambda': 3.9529552149151157, 'min_split_gain': 4.546811377375721e-08, 'min_child_weight': 0.02333321326179046, 'tpi_ngb': 240, 'n_splines': 12}. Best is trial 141 with value: 0.7347756890534961.
# [I 2025-01-15 23:28:59,888] Trial 143 finished with value: 0.7261227422239587 and parameters: {'n_estimators': 735, 'subsample': 0.9994872525813467, 'max_depth': 31, 'subsample_freq': 16, 'colsample_bytree': 0.951783882490067, 'tweedie_variance_power': 1.37950757162508, 'learning_rate': 0.003135416544098774, 'num_leaves': 11, 'min_child_samples': 46, 'reg_alpha': 0.3027142964892643, 'reg_lambda': 3.8850311347625053, 'min_split_gain': 4.715324523899063e-08, 'min_child_weight': 0.03134151575421659, 'tpi_ngb': 240, 'n_splines': 11}. Best is trial 141 with value: 0.7347756890534961.
# [I 2025-01-15 23:29:06,059] Trial 144 finished with value: 0.7277986991202117 and parameters: {'n_estimators': 1026, 'subsample': 0.9762127372265932, 'max_depth': 35, 'subsample_freq': 15, 'colsample_bytree': 0.9552317524082689, 'tweedie_variance_power': 1.4188772092045252, 'learning_rate': 0.0020646300551806487, 'num_leaves': 69, 'min_child_samples': 47, 'reg_alpha': 0.24392114989215372, 'reg_lambda': 5.34665509323562, 'min_split_gain': 4.592148606218271e-08, 'min_child_weight': 0.02534066350422544, 'tpi_ngb': 240, 'n_splines': 12}. Best is trial 141 with value: 0.7347756890534961.
# [I 2025-01-15 23:29:10,010] Trial 145 finished with value: 0.7334708054025951 and parameters: {'n_estimators': 842, 'subsample': 0.9884442677820635, 'max_depth': 34, 'subsample_freq': 17, 'colsample_bytree': 0.9873186259745774, 'tweedie_variance_power': 1.3685675490177012, 'learning_rate': 0.0048986017341040335, 'num_leaves': 26, 'min_child_samples': 46, 'reg_alpha': 0.3252605546393543, 'reg_lambda': 4.9230884552106025, 'min_split_gain': 5.660834164563276e-08, 'min_child_weight': 0.020238388545380754, 'tpi_ngb': 240, 'n_splines': 11}. Best is trial 141 with value: 0.7347756890534961.
# [I 2025-01-15 23:29:18,488] Trial 146 finished with value: 0.7222890788441388 and parameters: {'n_estimators': 1110, 'subsample': 0.9866024460868514, 'max_depth': 34, 'subsample_freq': 17, 'colsample_bytree': 0.9825950340264331, 'tweedie_variance_power': 1.4808014582448443, 'learning_rate': 0.005190847738106159, 'num_leaves': 91, 'min_child_samples': 44, 'reg_alpha': 0.31093223290276945, 'reg_lambda': 4.097166545957164, 'min_split_gain': 5.47341077273461e-08, 'min_child_weight': 0.04085533906346152, 'tpi_ngb': 240, 'n_splines': 10}. Best is trial 141 with value: 0.7347756890534961.
# [I 2025-01-15 23:29:23,108] Trial 147 finished with value: 0.7329982008352086 and parameters: {'n_estimators': 974, 'subsample': 0.9749209819531068, 'max_depth': 33, 'subsample_freq': 16, 'colsample_bytree': 0.9628605673665108, 'tweedie_variance_power': 1.399834838520012, 'learning_rate': 0.00297580650944511, 'num_leaves': 34, 'min_child_samples': 46, 'reg_alpha': 0.20094622302661677, 'reg_lambda': 2.563268395487825, 'min_split_gain': 6.644699981584151e-08, 'min_child_weight': 0.01997337547570461, 'tpi_ngb': 240, 'n_splines': 12}. Best is trial 141 with value: 0.7347756890534961.
# [I 2025-01-15 23:29:26,951] Trial 148 finished with value: 0.7330910884881426 and parameters: {'n_estimators': 776, 'subsample': 0.9754362283106454, 'max_depth': 33, 'subsample_freq': 16, 'colsample_bytree': 0.9919961041780053, 'tweedie_variance_power': 1.4030373991566665, 'learning_rate': 0.003267880897856303, 'num_leaves': 30, 'min_child_samples': 46, 'reg_alpha': 0.18988963792620023, 'reg_lambda': 2.655107880320676, 'min_split_gain': 6.31166321322467e-08, 'min_child_weight': 0.018892362892737064, 'tpi_ngb': 240, 'n_splines': 12}. Best is trial 141 with value: 0.7347756890534961.
# [I 2025-01-15 23:29:30,983] Trial 149 finished with value: 0.7328513047551487 and parameters: {'n_estimators': 783, 'subsample': 0.9933989164756688, 'max_depth': 33, 'subsample_freq': 15, 'colsample_bytree': 0.9920931113512925, 'tweedie_variance_power': 1.393906532232274, 'learning_rate': 0.006279884675832452, 'num_leaves': 31, 'min_child_samples': 44, 'reg_alpha': 0.20872909276538518, 'reg_lambda': 2.7301359206987805, 'min_split_gain': 6.21215314803529e-08, 'min_child_weight': 0.019362902705005434, 'tpi_ngb': 240, 'n_splines': 12}. Best is trial 141 with value: 0.7347756890534961.
# Best trial:
#   Value:  0.7347756890534961
#   Params:
#     n_estimators: 1149
#     subsample: 0.9761096708362259
#     max_depth: 34
#     subsample_freq: 16
#     colsample_bytree: 0.9473248299715323
#     tweedie_variance_power: 1.407663068135031
#     learning_rate: 0.003065732381164207
#     num_leaves: 23
#     min_child_samples: 46
#     reg_alpha: 0.30629005023048184
#     reg_lambda: 5.2217107812405485
#     min_split_gain: 4.752879344329507e-08
#     min_child_weight: 0.026347269517283937
#     tpi_ngb: 240
#     n_splines: 12
